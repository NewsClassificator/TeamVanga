# %%
# !pip install pymorphy3
# Out:
# Collecting pymorphy3
#   Downloading pymorphy3-2.0.6-py3-none-any.whl.metadata (2.4 kB)
# Collecting dawg2-python>=0.8.0 (from pymorphy3)
#   Downloading dawg2_python-0.9.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting pymorphy3-dicts-ru (from pymorphy3)
#   Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: setuptools>=68.2.2 in /usr/local/lib/python3.12/dist-packages (from pymorphy3) (75.2.0)
# Downloading pymorphy3-2.0.6-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 2.3 MB/s eta 0:00:00
# Downloading dawg2_python-0.9.0-py3-none-any.whl (9.3 kB)
# Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 65.3 MB/s eta 0:00:00
# Installing collected packages: pymorphy3-dicts-ru, dawg2-python, pymorphy3
# Successfully installed dawg2-python-0.9.0 pymorphy3-2.0.6 pymorphy3-dicts-ru-2.4.417150.4580142

# %%
import re
import pymorphy3

morph = pymorphy3.MorphAnalyzer()

def count_syllables(word):
    vowels = 'аеёиоуыэюяАЕЁИОУЫЭЮЯ'
    return sum(1 for char in word if char in vowels)

def analyze_text_simple(text):
    sentences = [s.strip() for s in re.split(r'[.!?…]+', text) if s.strip()]

    words = re.findall(r'\b[а-яА-ЯёЁ]+\b', text)

    syllables = 0
    for word in words:
        parsed = morph.parse(word)[0]
        syllables += count_syllables(parsed.normal_form)

    return len(sentences), len(words), syllables

def calculate_readability_index(text):
  sentences, words, syllables = analyze_text_simple(text)

  index = 206.835 - 1.3 * (words/sentences) - 60.1 * (syllables/words)

  if index > 90:
    return index, "ОЧЕНЬ ВЫСОКИЙ"
  elif index > 80:
    return index, "ВЫСОКИЙ"
  elif index > 70:
    return index, "ВЫШЕ СРЕДНЕГО"
  elif index > 60:
    return index, "СРЕДНИЙ"
  elif index > 50:
    return index, "НИЖЕ СРЕДНЕГО"
  elif index > 30:
    return index, "НИЗКИЙ"
  else:
    return index, "ОЧЕНЬ НИЗКИЙ"

# %%
if __name__ == "__main__":
  while user_text != "stop":
    user_text = input('Введите текст:')
    print(calculate_readability_index(user_text))
# Out:
# Введите текст:Катится колобок по дороге, а навстречу ему заяц:  – Колобок, колобок! Я тебя съем!  – Нет, не ешь меня, косой, а лучше послушай, какую я тебе песенку спою.  Заяц уши поднял, а колобок запел:    Я колобок, колобок! По амбару метён, По сусечкам скребён, На сметане мешён, В печку сажён, На окошке стужён. Я от дедушки ушёл, Я от бабушки ушёл. От тебя, зайца, не хитро уйти.
# (83.20084821428573, 'ВЫСОКИЙ')
# Введите текст:Жители юга России и Северного Кавказа заключили безопасные сделки на общую сумму 88,5 млрд руб. по почти 17 тыс. договоров за 11 месяцев 2025 года. Число операций с аккредитивами в Южном и Северо-Кавказском федеральных округах выросло на 36% по сравнению с аналогичным периодом 2024 года. Об этом сообщили в пресс-службе Юго-Западного банка Сбербанка.  «Рост популярности аккредитивов у физических лиц есть по всей стране, но южные регионы самые динамичные. Если за 11 месяцев число таких операций в РФ выросло на 17% к аналогичному периоду прошлого года, то на Юге это 36%. Высокую частоту дают и привычные сделки с жильем и довольно нетипичные ситуации. К примеру, покупка премиальных велосипедов. Три самых частых жизненных ситуаций южан, где применяется аккредитив не в сфере недвижимости — это покупка автомобиля, сохранение разных форм инвестиций и операции с долями бизнеса», — отметила Наталия Жарикова, директор управления торгового финансирования и документарных операций Юго-Западного Сбербанка.  Эксперты отметили растущий южный тренд и на оформление договоров на ремонтные и отделочные работы в четвертом квартале 2025 года. Самым редким видом стал раздел имущества по брачным договорам: им воспользовались 23 семьи. По прогнозам аналитиков, в декабре и весь 2026 год динамичнее всего будут расти сегменты авто, обучения и долгосрочных услуг.  Аккредитив — специальный банковский счет, где резервируется нужная для совершения сделки или выполнения обязательств сумма, и только при выполнении всех условий продавец получит деньги, а покупатель — актив, товар или услугу.  Например, после официальной регистрации перехода права собственности на автомобиль или недвижимость. Для открытия аккредитива нужно 10 минут, расчеты проходят за 1-2 дня в зависимости от структуры и сложности сделки.
# (36.986738609112706, 'НИЗКИЙ')
# Введите текст:ЕС торопится принять решение о бессрочной блокировке активов РФ, чтобы обойти возможное вето со стороны Венгрии — FT со ссылкой на источники.  Для этого планируется принятие закона, который предусматривает чрезвычайные полномочия для преодоления национального вето на продление санкций.
# (23.16833333333335, 'ОЧЕНЬ НИЗКИЙ')
# Введите текст:«Единственный западный лидер, который заботится о правах человека - Дональд Трамп» — Лавров.
# (45.01681818181817, 'НИЗКИЙ')
# Введите текст:Доставка Перекрёстка выпустила коллекцию новогодних аксессуаров в честь еды — сейчас это настоящий тренд. В капсулу под названием «Салатовые дни» вошли handmade чепчики в виде главных новогодних блюд: Оливье, Селёдки под шубой, Мимозы и Бутерброда с красной икрой.  Вся красота сделана вручную локальными вязальщицами. Главное: купить стиль нельзя, только выиграть в конкурсе в Телеграм-канале Перекрёстка с 9 по 15 декабря.
# (58.620526315789476, 'НИЖЕ СРЕДНЕГО')
# Введите текст:Самозанятые уже с 1 января смогут брать самобольничные. В России стартует эксперимент, позволяющий самозанятым официально приболеть.   Для этого нужно будет оформить самостраховку и ежемесячно уплачивать взносы 1300 руб. или 1900 руб. в месяц в Социальный фонд. А когда решите взять больничный или в случае травмы — сможете рассчитывать на выплаты от 35 000 до 50 000 руб. Больничный лист придётся оформлять в медицинском учреждении, так же, как при работе по найму.
# (68.25722222222224, 'СРЕДНИЙ')
# Введите текст:В Самокате появился практически весь модельный ряд Crocs, причём по ценам, которые вы не найдёте ни в одном магазине. Есть почти все модели и расцветки за 1,5-2 тысячи рублей. Даже те, о существовании которых вы могли не знать.  Также недавно в соцсетях удивлялись, что в Самокате появились ботинки Dr. Martens по ценам, в несколько раз дешевле магазинных. А люди, купившие их, рассказывают, что даже проверка по штрих-коду показывает оригинал.
# (73.24560606060605, 'ВЫШЕ СРЕДНЕГО')
# Введите текст:Российский бренд DNK выпустил одежду в честь советского пломбира и сгущёнки. Это утеплённые зимние костюмы и футболки.   К огорчению для ностальгирующих по советскому мороженому, костюмы есть только на детей и подростков. А вот оверсайз-футболки могут попробовать натянуть и взрослые. Костюмы для малых обойдутся в 9900 рублей, за футболку попросят не советские 4500 рублей.
# (67.4828431372549, 'СРЕДНИЙ')
# Введите текст:Учительницa на уроке: — Рeбята, дoлжна вам сказать, что у вас не очень обстоят дела с математикой. Я думаю, что 80% из класса не сдаст экзамен.  Голoс из класса: — Да нас здeсь стoлько и не набeрется.
# (108.3238888888889, 'ОЧЕНЬ ВЫСОКИЙ')
# Введите текст:Одного парня заколдовала колдунья: он мог говорить только одно слово в год. Спустя 4 года колдунья к нему вернулась: — Ну что, готов извиняться? — 250 и по рукам Раньше парень был глухонемым.
# (80.28557471264368, 'ВЫСОКИЙ')
# Введите текст:Однажды один человек встретил джина, и тот сказал ему:  — Я исполню любые твои желания, но что бы ты не загадал, — твой сосед, которого ты ненавидишь, получит вдвое больше. — Я хочу ведро раков  У соседа утонула жена
# (69.91277777777778, 'СРЕДНИЙ')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3642962204.py in <cell line: 0>()
#       1 if __name__ == "__main__":
#       2   while user_text != "stop":
# ----> 3     user_text = input('Введите текст:')
#       4     print(calculate_readability_index(user_text))
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
